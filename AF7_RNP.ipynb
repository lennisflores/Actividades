# %% [markdown]
# ## **AF7: Redes Neuronales Artificiales**

# %%
#INT.ARTIFICIALY REDES NEURONALES N4 Gpo 008
#AF7: Redes Neuronales Artificiales
#2022917 FLORES ARREOLA LENNIS VALERIA
#2044749 HERNÁNDEZ SANTILLAN JOSUE URIEL
#2001320 OLIVA ESTRADA XOCHITL
#2108228 TORRES RAMOS JARED ISAI
#2222972 DE SANTIAGO PÉREZ MARÍA TERESA

# %% [markdown]
# **Objetivo:**
#
#
# Entrenar un modelo de Red Neuronal Prealimentada (tipo feedforward).

# %% [markdown]
# 1. Importar librerías

# %%
import tensorflow as tf
import keras
import numpy as np
import matplotlib.pyplot as plt
print(tf.__version__)
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()
# Out:
# 2.20.0
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# 2. Cargar datos

# %%
train_images = x_train.reshape((60_000, 28 * 28))
train_images = train_images.astype('float32') / 255
test_images = x_test.reshape((10_000, 28 * 28))
test_images = test_images.astype('float32') / 255

# %% [markdown]
# 3. Preprocesamiento de datos

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Input, Dense, Flatten
model = Sequential([
    Input(shape=(28 * 28,)),
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(16, activation='relu'),
    Dense(10, activation='softmax')
])
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# 4. Selección y entrenamiento del modelo

# %%
model.fit(train_images, y_train, epochs=25)
# Out:
# Epoch 1/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.8997 - loss: 0.3346
# Epoch 2/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9581 - loss: 0.1397
# Epoch 3/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.9689 - loss: 0.1027
# Epoch 4/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9744 - loss: 0.0838
# Epoch 5/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9788 - loss: 0.0683
# Epoch 6/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9818 - loss: 0.0583
# Epoch 7/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9833 - loss: 0.0514
# Epoch 8/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9856 - loss: 0.0437
# Epoch 9/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9872 - loss: 0.0395
# Epoch 10/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9887 - loss: 0.0354
# Epoch 11/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9897 - loss: 0.0315
# Epoch 12/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9899 - loss: 0.0300
# Epoch 13/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9910 - loss: 0.0266
# Epoch 14/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9914 - loss: 0.0250
# Epoch 15/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9923 - loss: 0.0221
# Epoch 16/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9926 - loss: 0.0227
# Epoch 17/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9941 - loss: 0.0178
# Epoch 18/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9940 - loss: 0.0190
# Epoch 19/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9945 - loss: 0.0169
# Epoch 20/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9941 - loss: 0.0177
# Epoch 21/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.9946 - loss: 0.0156
# Epoch 22/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9953 - loss: 0.0143
# Epoch 23/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9949 - loss: 0.0148
# Epoch 24/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9951 - loss: 0.0141
# Epoch 25/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9959 - loss: 0.0125

# %%
test_loss, test_acc = model.evaluate(test_images, y_test, verbose=2)
print('\nTest accuracy:', test_acc)
# Out:
# 313/313 - 1s - 2ms/step - accuracy: 0.9741 - loss: 0.1566
#
# Test accuracy: 0.9740999937057495

# %% [markdown]
# 5. Prueba del modelo

# %%
predictions = model.predict(test_images)
def mostrar_predicciones(n=5):
    plt.figure(figsize=(10, 2 * n))
    for i in range(n):
        imagen = x_test[i].reshape(28, 28)
        entrada = test_images[i].reshape(1, 784)
        pred = model.predict(entrada)
        prediccion = np.argmax(pred)
        etiqueta_real = y_test[i]
        color = 'blue' if prediccion == etiqueta_real else 'red'
        plt.subplot(n, 1, i + 1)
        plt.imshow(imagen, cmap='gray')
        plt.title(f"Predicción: {prediccion} | Valor real: {etiqueta_real}", color=color)
        plt.axis('off')
    plt.tight_layout()
    plt.show()
mostrar_predicciones(5)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
